# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramchand-Bethireddy/solutions/blob/main/linear_regression_(film_revenue).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/cost_revenue_clean (1).csv')
df
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
df.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
df.shape
# Out:
# (5034, 2)

# %%
#X=df["production_budget_usd"].values (to take values just like in array)
#X
#y=df["worldwide_gross_usd"].values
#y
x=DataFrame(df,columns=['production_budget_usd'])
y=DataFrame(df,columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.title("film cost vs gross worldwide film revenue")
plt.xlabel("production cost $")
plt.ylabel("world gross $")
plt.xlim(0,450000000)
plt.ylim(0,3000000000)
plt.show()

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[3.11150918]])

# %%
reg.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.plot(x,reg.predict(x),color='red',linewidth=4)
plt.title("film cost vs gross worldwide film revenue")
plt.xlabel("production cost $")
plt.ylabel("world gross $")
plt.xlim(0,450000000)
plt.ylim(0,3000000000)
plt.show()

# %%
reg.score(x,y)
# Out:
# 0.5496485356985729
